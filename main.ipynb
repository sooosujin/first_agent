# %%
import os
print(os.getenv("OPENAI_API_KEY"))
# Out:
# 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

# %%
import openai

client = openai.OpenAI()
messages = []

# %%
def call_ai():
  response = client.chat.completions.create(
        model="gpt-5-nano",
        messages=messages,
)
  message = response.choices[0].message.content
  messages.append({
    "role" : "assistant",
    "content" : message
  })
  print(f"AI: {message}")

# %%
while True:
  message = input("Send a message to the LLM...")
  if message == "quit" or message == "q":
      break
  else:
      messages.append({
        "role":"user",
        "content" : message,        
      })
      print(f"User: {message}")
      call_ai()
# Out:
# User: my name is su
# AI: Nice to meet you, Su! How can I help today?
#
# If you’re not sure yet, here are a few things I can do:
# - Answer questions or explain topics
# - Help with writing (emails, essays, resumes)
# - Plan a project, study schedule, or travel itinerary
# - Learn or practice a new skill (coding, languages, etc.)
# - Review or debug code
# - Translate or summarize text
# - Brainstorm ideas or solutions
#
# Would you like me to call you Su, or do you prefer a different name or pronouns? What would you like to work on first?
# User: what is my name
# AI: Your name is Su (as you told me). Would you like me to call you Su with that capitalization, or do you prefer something different? If you have a nickname or different spelling you’d like me to use, tell me.
# User: I'm live in Korea.
# AI: Nice to know you’re in Korea, Su. Would you like me to tailor things to Korea time (KST, UTC+9)? Do you want me to respond in Korean or English?
#
# Here are a few ways I can help related to living in Korea:
# - Practice Korean phrases (greetings, directions, ordering, everyday conversations)
# - Translate or summarize Korean text
# - Help with daily life topics (rent, utilities, transport, apps like KakaoTalk, Naver)
# - Plan trips or weekend itineraries in Korea
# - Help with resumes or job apps in Korean
# - Share cultural tips and etiquette
#
# What would you like to work on first?
# User: what wahs the first question i asked you?
# AI: The very first thing you wrote was a statement: "my name is su." The first actual question you asked was: "what is my name?"
# User: what was the first question i asked you and what is the closest Island country to where i lived?
# AI: - First question you asked: "what is my name?" (Your name is Su, as you told me.)
#
# - Closest island country to Korea: Japan. The southern part of Japan is just across the Korea Strait (e.g., Busan to Kyushu is only about 60–200 km depending on the exact points).
#
# If you want another reference, Taiwan is also an island country but farther away from Korea—roughly 1,700–1,900 km from Seoul. Want me to pull precise distances or travel times?
# User:
# AI: It looks like your message didn’t come through. What would you like to do next? Here are a few ideas:
#
# - More geography questions (e.g., distances between Korea and nearby countries/islands)
# - Korean language practice or translations
# - Help planning a trip or weekend activities in Korea
# - Korean resume/job app tips
# - Any other question or topic you have in mind
#
# Tell me what you’d like to focus on.
